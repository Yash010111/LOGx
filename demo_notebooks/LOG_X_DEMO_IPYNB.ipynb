# %%
from huggingface_hub import login
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import torch

HF_TOKEN = "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"
login(HF_TOKEN)

model_name = "google/gemma-2b-it"  # Smaller model

print("Loading model... (this can take a few minutes on first run)")

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float32  # Safe for CPU
)

tokenizer = AutoTokenizer.from_pretrained(model_name)

generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)

SYSTEM_PROMPT = (
    "You are a helpful technical log analysis and troubleshooting expert.\n"
    "When given a log or error message, you:\n"
    "1) Explain what the log likely means in simple terms.\n"
    "2) Suggest possible root causes.\n"
    "3) Recommend specific troubleshooting steps.\n"
)

def build_prompt(user_input):
    return f"{SYSTEM_PROMPT}\n\nLog:\n{user_input}\n\nResponse:"

print("\n✅ Chatbot ready! Type 'exit' to quit.\n")

while True:
    user_input = input("👤 Enter log or error: ").strip()
    if user_input.lower() in {"exit", "quit"}:
        break

    prompt = build_prompt(user_input)
    outputs = generator(
        prompt,
        max_new_tokens=300,
        temperature=0.3,
        do_sample=True,
        top_p=0.9
    )
    response = outputs[0]["generated_text"][len(prompt):].strip()
    print("\n🤖 Solution Expert:\n")
    print(response)
    print("\n" + "-" * 50 + "\n")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     656     try:
# --> 657         response.raise_for_status()
#     658     except httpx.HTTPStatusError as e:
#
# ...

# %% [markdown]
# # **1 Install and Import Required Libraries**

# %%
# Import libraries for model loading and text generation
from huggingface_hub import login
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import torch

# %% [markdown]
# # 2 Log in to Hugging Face Hub

# %%
HF_TOKEN = "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"

# Login to the Hugging Face hub to access the model
login(HF_TOKEN)

# %% [markdown]
# # 3 Define Model Name

# %%
model_name = "google/gemma-2b-it"

print("✅ Model name set:", model_name)
# Out:
# ✅ Model name set: google/gemma-2b-it

# %% [markdown]
# # 4 Load the Model and Tokenizer

# %%
print("Loading model... (this may take a few minutes on first run)")

# Load the model in CPU-safe mode
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float32  # Use float32 for CPU compatibility
)
tokenizer = AutoTokenizer.from_pretrained(model_name)



print("Model and tokennizer loaded successfully.")
# Out:
# Loading model... (this may take a few minutes on first run)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Model and tokennizer loaded successfully.

# %% [markdown]
# # 5 Initialize the Text Generation Pipeline

# %%
# Create a text-generation pipeline
generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)

print("✅ Text generation pipeline initialized.")
# Out:
# Device set to use cpu
# ✅ Text generation pipeline initialized.

# %% [markdown]
# # 6 Define the System Prompt

# %%
# This prompt guides the model to act like a log analysis expert
# Implement chain of thoughts
# Fine tune further using hyperparameters.
#
SYSTEM_PROMPT = (
    "You are a helpful technical log analysis and troubleshooting expert.\n"
    "When given a log or error message, you:\n"
    "1) Explain what the log likely means in simple terms.\n"
    "2) Suggest possible root causes.\n"
    "3) Recommend specific troubleshooting steps.\n"
)

# %% [markdown]
# # 7 Define Prompt Builder Function

# %%
# Function to build the complete prompt from user input
def build_prompt(user_input):
    return f"{SYSTEM_PROMPT}\n\nLog:\n{user_input}\n\nResponse:"

# %% [markdown]
# # 8 Define a Sample Log for Demo {"ERROR 503: Service Unavailable. Backend server did not respond within the timeout period."}

# %%
# Example log to demonstrate model output
sample_log = "ERROR 503: Service Unavailable."
prompt = build_prompt(sample_log)
print("✅ Prompt built:\n")
print(prompt)
# Out:
# ✅ Prompt built:
#
# You are a helpful technical log analysis and troubleshooting expert.
# When given a log or error message, you:
# 1) Explain what the log likely means in simple terms.
# 2) Suggest possible root causes.
# 3) Recommend specific troubleshooting steps.
#
#
# Log:
# ERROR 503: Service Unavailable.
#
# Response:

# %% [markdown]
# # 9 Generate the Model Response

# %%
# Use the generator pipeline to get the explanation
outputs = generator(
    prompt,
    max_new_tokens=300,
    temperature=0.3,   # Lower temperature = more focused output
    do_sample=True,
    top_p=0.9          # Nucleus sampling for creativity
)

# Extract the model's response text
response = outputs[0]["generated_text"][len(prompt):].strip()

print("✅ Response generated.")
# Out:
# ✅ Response generated.

# %% [markdown]
# # 10 Display the Model's Analysis

# %%
print("\n🤖 Solution Expert:\n")
print(response)
print("\n" + "-" * 50 + "\n")
# Out:
# 🤖 Solution Expert:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-375/2965479738.py in <cell line: 0>()
#       1 print("\n🤖 Solution Expert:\n")
# ----> 2 print(response)
#       3 print("\n" + "-" * 50 + "\n")
#
# NameError: name 'response' is not defined
